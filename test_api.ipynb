# %%
import requests
id_client = 208893
url = "https://projet-7-implementation-d-un-modele-de.onrender.com/"
reponse = requests.get(f"{url}/prediction/{id_client}")
reponse.status_code
reponse.json()
# Out:
# {'client_id': 208893, 'probability_default': 0.9999999999999993}

# %%
reponse = requests.get(f"{url}/interpretabilite/{id_client}")

# %%
reponse
# Out:
# <Response [200]>
